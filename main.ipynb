# %% [markdown]
# # Project 4
#
# Stock price Predictor

# %% [markdown]
# Import packages

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf 
from pathlib import Path
import os
import sys
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Flatten, Conv2D, MaxPooling2D, concatenate, Conv1D, MaxPooling1D
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import roc_curve, auc, mean_squared_error
import matplotlib.pyplot as plt 
from collections.abc import Sequence
from sklearn import preprocessing
# %matplotlib inline
import csv
import glob
from IPython.display import Image
import seaborn as sns

# %% [markdown]
# ### Define Helper Methods

# %%
def plot_losses(history, base_path, iteration:int):
    # Plot training & validation loss over epochs
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.ylim(bottom=0.0, top=10.0)
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training vs. Validation Loss")
    plt.legend()
    plt.savefig(
        os.path.join(base_path, f"training-validiation-loss--epoch---Model {iteration}")
    )
    plt.close()


def print_schema(dataframe: pd.DataFrame):
    print('~~~~~~dataframe schema~~~~~~')
    print(f"Dataframe shape: {dataframe.shape} | Dataframe length: {len(dataframe)}")
    print('Column labels: ')
    print(dataframe.columns)
    print('Dataframe head: ')
    print(f"{dataframe.head()}")
def print_column(dataframe: pd.DataFrame, columns: str | list[str]):
    if isinstance(columns, list):
        for i, label in enumerate(columns):
            print(f"column {i}")
            print(dataframe[label])
    else:
        print(dataframe[columns])
# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)


# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_


# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Convert all missing values in the specified column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)


# Convert all missing values in the specified column to the default
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)


# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column. 
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    #if target_type in (np.int64, np.int32):
        ## Classification
        #dummies = pd.get_dummies(df[target])
        #return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    #else#:
        ## Regression
    return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


# Regression chart.
def chart_regression(path, pred,y,sort=True):
    t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
    if sort:
        t.sort_values(by=['y'],inplace=True)
    b = plt.plot(t['pred'].tolist(),label='prediction')
    a = plt.plot(t['y'].tolist(),label='expected')

    plt.ylabel('output')
    plt.legend()
    plt.savefig(path)
    plt.close()

# Remove all rows where the specified column is +/- sd standard deviations
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd * df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)


# Encode a column to a range between normalized_low and normalized_high.
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = min(df[name])
        data_high = max(df[name])

    df[name] = ((df[name] - data_low) / (data_high - data_low)) \
               * (normalized_high - normalized_low) + normalized_low

# %% [markdown]
# ### Global Control Flow Flags
#
# These flags are used for control flow and debugging.

# %%
DEBUG = True
ITERATION = 57
WINDOW_SIZE = 7
INPUT_IS_TWO_DIMENSIONAL = False
EXPLORE = False
FCN = False
CNN = True
RNN = False

# %% [markdown]
# ### Output Files
#
# Define paths for output files like charts, tests, and metrics

# %%
base_path = os.path.join(os.getcwd(), "output")
iteration_path = os.path.join(base_path, f"iteration-{ITERATION}")
try:
    os.mkdir(base_path)
except FileExistsError as e:
    print(f"{base_path} already exists")
except OSError as e:
    print(f"Error creating directory: {base_path}")
try:
    os.mkdir(iteration_path)
except FileExistsError as e:
    print(f"{iteration_path} already exists. Exiting to preserve previous work.")
    sys.exit(0)
except OSError:
    print("An error occurred while creating the folder. ")
# Out:
# c:\Users\timef\Documents\Workspaces\Python\csc180\stock-price-predictor\output already exists
# c:\Users\timef\Documents\Workspaces\Python\csc180\stock-price-predictor\output\iteration-57 already exists. Exiting to preserve previous work.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\timef\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### Read Dataset

# %%
df = pd.read_csv("./data/JPM.csv", dtype={'Volume':np.float32})
print("hit")
# Out:
# hit

# %% [markdown]
# ### Drop Unneccessary Columns

# %%
df.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %%
if DEBUG:
    print(df.columns)
    print(df.dtypes)
    print(df.shape)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float32
# dtype: object
# (9745, 5)

# %% [markdown]
# ### Perform Data Cleaning
# First, seperate the "y" output feature from the "y" input feature
# Second, fill in missing values with the median.
# Third, encode the input feature columns.

# %%
df_copy = df.copy(deep=True)
missing_median(df_copy, 'Close')
for column in df.columns:
    missing_median(df, column)
    if column == 'Close':
        continue
    else:
        encode_numeric_zscore(df, column)

# %% [markdown]
# ### Reshape Input
#
# Reshape the input dataframe so the model ingests the last 7 days as 1 record.

# %%
if FCN or CNN:
    x = []
    y = []
    window_size = WINDOW_SIZE
    for i in range(len(df) - window_size):
        window = df.iloc[i:i+window_size][['Open', 'High', 'Low', 'Volume', 'Close']].values
        x.append(window.flatten())
        y.append(df_copy.iloc[i+window_size]['Close'])

    X = np.array(x)
    Y = np.array(y)

# %% [markdown]
# ### Reshaping for CNN
# Reshape the input to be a be an 'image' with 7 rows, 5 columns, 1 channel. (2D array)

# %%
if CNN and INPUT_IS_TWO_DIMENSIONAL:
    X = X.reshape((X.shape[0], WINDOW_SIZE,5,1))
    print(X.shape)
    print(Y.shape)
if CNN and not INPUT_IS_TWO_DIMENSIONAL:
    X = X.reshape((X.shape[0], WINDOW_SIZE, 5))
    print(X.shape)
    print(Y.shape)
# Out:
# (9738, 7, 5, 1)
# (9738,)

# %%
if DEBUG:
    print(df.shape)
    for column in df.columns:
        print(f"Number of NAN values in {column}: {df[column].isna().sum()}")
# Out:
# (9745, 5)
# Number of NAN values in Open: 0
# Number of NAN values in High: 0
# Number of NAN values in Low: 0
# Number of NAN values in Close: 0
# Number of NAN values in Volume: 0

# %%
# y = df['Close']
# don't use a random shuffling. This completely breaks the chronological order of the data. 
split_at_index = int(len(X) * 0.7) # we want the training set to have 70% of the rows in the raw df
x_train, x_test = X[:split_at_index], X[split_at_index:]
y_train, y_test = Y[:split_at_index], Y[split_at_index:]  
#x_train, x_test, y_train, y_test = train_test_split(X,Y, random_state=42, test_size=0.3)

# %%
if DEBUG:
    print(X)
    print('-----------')
    print(Y)
    print("--------------")
    print(f"X-Train Shape: {x_train.shape}")
    print(f"Y-Train Shape: {y_train.shape}")
    print(f"X-Test Shape: {x_test.shape}")
    print(f"Y-Test Shape: {y_test.shape}")
# Out:
# [[-1.16962972e+00 -1.17092224e+00 -1.16332275e+00 ... -1.16174374e+00
#   -6.72499359e-01  5.07407400e+00]
#  [-1.16884723e+00 -1.17169789e+00 -1.16253322e+00 ... -1.16253322e+00
#   -6.74830973e-01  5.11111100e+00]
#  [-1.16571735e+00 -1.16937098e+00 -1.15937519e+00 ... -1.16727027e+00
#   -6.73069298e-01  5.07407400e+00]
#  ...
#  [ 3.18802549e+00  3.15195649e+00  3.14656018e+00 ...  3.09326832e+00
#    3.60764503e-01  1.06699997e+02]
#  [ 3.02112437e+00  3.06064937e+00  3.04381330e+00 ...  3.21818445e+00
#    5.24282932e-01  1.09019997e+02]
#  [ 3.04478649e+00  3.01332007e+00  3.01013314e+00 ...  3.24078016e+00
#    7.55183548e-02  1.08980003e+02]]
# -----------
# [  5.111111   5.074074   5.018518 ... 109.019997 108.980003 108.379997]
# --------------
# X-Train Shape: (6816, 35)
# Y-Train Shape: (6816,)
# X-Test Shape: (2922, 35)
# Y-Test Shape: (2922,)

# %% [markdown]
# ### Create Model

# %%
checkpoint_path = os.path.join(iteration_path, "FCN-best-weights.keras")
#os.mkdir(checkpoint_path) # this is wrong

# %% [markdown]
# ### Create a FCN

# %%
if FCN:
    checkpointer = ModelCheckpoint(filepath=checkpoint_path, save_best_only=True, verbose=0)
    for i in range(5):

        visible = Input(shape=(x_train.shape[1],))
        hidden1 = Dense(256, activation='relu')(visible)
        hidden2=Dense(256, activation='relu')(hidden1)
        hidden3=Dense(128, activation='relu')(hidden2)
        hidden4 = Dense(64, activation='relu')(hidden3)
        hidden5 = Dense(32, activation='relu')(hidden4)
        hidden6=Dense(16, activation='relu')(hidden5)
        hidden7=Dense(8, activation='relu')(hidden6)
        hidden8 = Dense(4, activation='relu')(hidden7)

        output = Dense(1)(hidden8)
        model = Model(inputs=visible, outputs=output)
        model.compile(loss='mean_squared_error', optimizer='adam')
        monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=10, verbose=2, mode='min', restore_best_weights=True)
        history = model.fit(x_train, y_train, validation_data=[x_test, y_test], epochs=1000, callbacks=[checkpointer, monitor])
        plot_losses(history, iteration_path, i)
# Out:
# Epoch 1/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 730.5724 - val_loss: 3656.7437
# Epoch 2/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 706.5835 - val_loss: 3585.7217
# Epoch 3/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 675.2579 - val_loss: 3494.8086
# Epoch 4/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 637.6918 - val_loss: 3386.8943
# Epoch 5/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 595.7300 - val_loss: 3265.2954
# Epoch 6/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 551.3072 - val_loss: 3134.8552
# Epoch 7/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 506.1922 - val_loss: 2997.0129
# Epoch 8/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 462.0011 - val_loss: 2856.2527
# Epoch 9/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 420.1260 - val_loss: 2715.4314
# Epoch 10/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 381.7910 - val_loss: 2577.7063
# Epoch 11/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 347.6920 - val_loss: 2444.8845
# Epoch 12/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 318.3928 - val_loss: 2319.7917
# Epoch 13/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 294.1929 - val_loss: 2203.8696
# Epoch 14/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 274.9943 - val_loss: 2098.6748
# Epoch 15/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 260.4731 - val_loss: 2006.2139
# Epoch 16/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 250.0613 - val_loss: 1926.3649
# Epoch 17/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 242.9901 - val_loss: 1859.6439
# Epoch 18/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 238.4915 - val_loss: 1806.6866
# Epoch 19/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 235.8508 - val_loss: 1764.2330
# Epoch 20/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 234.4131 - val_loss: 1732.2245
# Epoch 21/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.6741 - val_loss: 1710.2831
# Epoch 22/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.3287 - val_loss: 1693.8706
# Epoch 23/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.2016 - val_loss: 1684.5917
# Epoch 24/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1511 - val_loss: 1678.3477
# Epoch 25/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1232 - val_loss: 1673.7939
# Epoch 26/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1256 - val_loss: 1674.9030
# Epoch 27/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1158 - val_loss: 1672.0034
# Epoch 28/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1198 - val_loss: 1668.6080
# Epoch 29/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1182 - val_loss: 1670.1333
# Epoch 30/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1124 - val_loss: 1669.8544
# Epoch 31/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1236 - val_loss: 1670.5448
# Epoch 32/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1223 - val_loss: 1670.6609
# Epoch 33/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1173 - val_loss: 1670.5366
# Epoch 34/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1259 - val_loss: 1671.7938
# Epoch 35/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1182 - val_loss: 1669.7356
# Epoch 36/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1185 - val_loss: 1667.6597
# Epoch 37/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1227 - val_loss: 1667.3702
# Epoch 38/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1219 - val_loss: 1665.2587
# Epoch 39/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1243 - val_loss: 1668.1222
# Epoch 40/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1115 - val_loss: 1670.4211
# Epoch 41/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1236 - val_loss: 1670.1807
# Epoch 42/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1303 - val_loss: 1668.2057
# Epoch 43/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1174 - val_loss: 1673.7301
# Epoch 44/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1149 - val_loss: 1668.2797
# Epoch 45/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1181 - val_loss: 1668.0728
# Epoch 46/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1183 - val_loss: 1665.8911
# Epoch 47/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 233.1330 - val_loss: 1667.6708
# Epoch 48/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 233.1214 - val_loss: 1668.6411
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 38.
# Epoch 1/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 126.0486 - val_loss: 7.0027
# Epoch 2/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9842 - val_loss: 3.8235
# Epoch 3/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9619 - val_loss: 2.5666
# Epoch 4/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8998 - val_loss: 2.7193
# Epoch 5/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8180 - val_loss: 2.0765
# Epoch 6/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7411 - val_loss: 1.9286
# Epoch 7/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6545 - val_loss: 2.0743
# Epoch 8/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6643 - val_loss: 1.8725
# Epoch 9/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6571 - val_loss: 2.7671
# Epoch 10/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6673 - val_loss: 3.1451
# Epoch 11/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5644 - val_loss: 1.6575
# Epoch 12/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5576 - val_loss: 1.6671
# Epoch 13/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6573 - val_loss: 3.0648
# Epoch 14/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5190 - val_loss: 2.5049
# Epoch 15/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5520 - val_loss: 1.4508
# Epoch 16/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6168 - val_loss: 1.4818
# Epoch 17/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5409 - val_loss: 1.5612
# Epoch 18/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5109 - val_loss: 1.6420
# Epoch 19/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6098 - val_loss: 1.5552
# Epoch 20/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5446 - val_loss: 1.3428
# Epoch 21/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7189 - val_loss: 3.6461
# Epoch 22/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5902 - val_loss: 3.4525
# Epoch 23/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6350 - val_loss: 2.2078
# Epoch 24/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5194 - val_loss: 1.2875
# Epoch 25/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5655 - val_loss: 1.7196
# Epoch 26/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8223 - val_loss: 2.4282
# Epoch 27/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5177 - val_loss: 2.8702
# Epoch 28/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5547 - val_loss: 1.2900
# Epoch 29/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5749 - val_loss: 2.1745
# Epoch 30/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4764 - val_loss: 1.2546
# Epoch 31/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5270 - val_loss: 2.7343
# Epoch 32/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6506 - val_loss: 1.4721
# Epoch 33/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5523 - val_loss: 3.8654
# Epoch 34/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6080 - val_loss: 3.8907
# Epoch 35/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5942 - val_loss: 1.2558
# Epoch 36/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5023 - val_loss: 1.6159
# Epoch 37/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4483 - val_loss: 1.5368
# Epoch 38/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5474 - val_loss: 1.6022
# Epoch 39/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4896 - val_loss: 6.4860
# Epoch 40/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7065 - val_loss: 1.2860
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Epoch 1/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 31.0992 - val_loss: 3.5709
# Epoch 2/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0757 - val_loss: 2.4833
# Epoch 3/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8975 - val_loss: 2.3799
# Epoch 4/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6946 - val_loss: 2.4408
# Epoch 5/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6727 - val_loss: 4.3400
# Epoch 6/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6333 - val_loss: 1.5637
# Epoch 7/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5302 - val_loss: 2.1792
# Epoch 8/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6513 - val_loss: 1.3616
# Epoch 9/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7350 - val_loss: 1.4510
# Epoch 10/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6656 - val_loss: 8.8775
# Epoch 11/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6466 - val_loss: 2.5008
# Epoch 12/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7299 - val_loss: 4.5045
# Epoch 13/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6170 - val_loss: 1.3906
# Epoch 14/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6033 - val_loss: 5.0192
# Epoch 15/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5606 - val_loss: 1.5047
# Epoch 16/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6483 - val_loss: 3.5410
# Epoch 17/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5160 - val_loss: 2.3848
# Epoch 18/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6514 - val_loss: 3.4088
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 8.
# Epoch 1/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 50.1276 - val_loss: 2.8620
# Epoch 2/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9468 - val_loss: 2.2112
# Epoch 3/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8509 - val_loss: 3.9380
# Epoch 4/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7486 - val_loss: 2.1429
# Epoch 5/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8134 - val_loss: 2.2240
# Epoch 6/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6683 - val_loss: 1.8480
# Epoch 7/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6122 - val_loss: 1.9353
# Epoch 8/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5461 - val_loss: 1.9475
# Epoch 9/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5883 - val_loss: 2.5871
# Epoch 10/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5680 - val_loss: 4.1458
# Epoch 11/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6324 - val_loss: 4.2769
# Epoch 12/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5892 - val_loss: 3.1442
# Epoch 13/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6176 - val_loss: 3.2532
# Epoch 14/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6708 - val_loss: 9.4421
# Epoch 15/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7367 - val_loss: 1.4024
# Epoch 16/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7505 - val_loss: 4.1643
# Epoch 17/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4814 - val_loss: 2.3233
# Epoch 18/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4858 - val_loss: 1.3139
# Epoch 19/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6832 - val_loss: 2.0757
# Epoch 20/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5197 - val_loss: 1.3692
# Epoch 21/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5593 - val_loss: 5.0393
# Epoch 22/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6135 - val_loss: 7.3812
# Epoch 23/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6380 - val_loss: 1.4762
# Epoch 24/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6671 - val_loss: 1.2983
# Epoch 25/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5323 - val_loss: 1.5222
# Epoch 26/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5186 - val_loss: 1.2561
# Epoch 27/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4738 - val_loss: 1.2593
# Epoch 28/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6292 - val_loss: 1.3268
# Epoch 29/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6469 - val_loss: 1.8645
# Epoch 30/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7227 - val_loss: 2.9086
# Epoch 31/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5150 - val_loss: 4.1440
# Epoch 32/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6105 - val_loss: 1.5023
# Epoch 33/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5988 - val_loss: 4.7255
# Epoch 34/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5365 - val_loss: 1.8687
# Epoch 35/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5487 - val_loss: 1.5285
# Epoch 36/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5634 - val_loss: 3.0739
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# Epoch 1/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 18.1223 - val_loss: 2.4622
# Epoch 2/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7681 - val_loss: 3.9430
# Epoch 3/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6718 - val_loss: 1.6449
# Epoch 4/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5570 - val_loss: 2.0239
# Epoch 5/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6997 - val_loss: 2.5946
# Epoch 6/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5575 - val_loss: 2.4524
# Epoch 7/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5892 - val_loss: 1.6233
# Epoch 8/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5246 - val_loss: 1.8333
# Epoch 9/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5935 - val_loss: 2.5640
# Epoch 10/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7973 - val_loss: 1.6147
# Epoch 11/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6884 - val_loss: 2.8748
# Epoch 12/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5741 - val_loss: 1.6534
# Epoch 13/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6757 - val_loss: 1.5142
# Epoch 14/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5489 - val_loss: 1.7932
# Epoch 15/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6750 - val_loss: 4.4604
# Epoch 16/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6055 - val_loss: 5.4309
# Epoch 17/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7075 - val_loss: 1.8308
# Epoch 18/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5163 - val_loss: 1.2463
# Epoch 19/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5126 - val_loss: 1.2821
# Epoch 20/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4983 - val_loss: 1.2423
# Epoch 21/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5533 - val_loss: 1.3036
# Epoch 22/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7218 - val_loss: 4.9652
# Epoch 23/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5370 - val_loss: 2.3381
# Epoch 24/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4944 - val_loss: 1.2038
# Epoch 25/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7580 - val_loss: 7.5704
# Epoch 26/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6078 - val_loss: 4.0310
# Epoch 27/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5802 - val_loss: 1.2062
# Epoch 28/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5599 - val_loss: 1.4795
# Epoch 29/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5279 - val_loss: 1.4100
# Epoch 30/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4772 - val_loss: 4.6742
# Epoch 31/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4927 - val_loss: 1.3219
# Epoch 32/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5347 - val_loss: 1.4829
# Epoch 33/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5249 - val_loss: 1.3288
# Epoch 34/1000
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5552 - val_loss: 1.5776
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %% [markdown]
# ### Evaluate the Model

# %%
if FCN:
    metrics_path = "FCN-metrics.txt"
    # Write Metrics to file
    def redirect(out): # redirect model summary to metrics
        with open(os.path.join(iteration_path, metrics_path), 'a') as file:
            print(out, file=file)

    model.load_weights(checkpoint_path)
    prediction = model.predict(x_test)
    score = np.sqrt(mean_squared_error(y_test, prediction))
    if DEBUG:
        print("Score (RMSE): {}".format(score))

    with open(os.path.join(iteration_path, metrics_path), "x") as file:
        file.write(f"Score (RMSE): {score}\n")
    model.summary(print_fn=redirect)
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Score (RMSE): 1.0972008127032644
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
if FCN:
    # Make Plots
    chart_regression(os.path.join(iteration_path, "FCN-Lift-Chart"), prediction.flatten(), y_test, sort=True)

# %% [markdown]
# ### Create a CNN

# %% [markdown]
# Create the model

# %%
if CNN and INPUT_IS_TWO_DIMENSIONAL: # 2D image of 7 * 5 = 35 pixels, each pixel with 1 channel.
    checkpointer = ModelCheckpoint(filepath=os.path.join(iteration_path, "CNN-best-weights.keras"), save_best_only=True, verbose=0)
    # H_out = floor((H_in + 2*pad_h - kernel_h) / stride_h) + 1
    # W_out = floor((W_in + 2*pad_w - kernel_w) / stride_w) + 1
    # C_out = number of filters

    # H_out = (7 - 4) / 1 + 1 = 4
    # W_out = (5 - 4) / 1 + 1 = 2
    # Channels_out = 64

    for i in range(5):
        visible = Input(shape=(WINDOW_SIZE,5,1)) 
        con1 = Conv2D(64, kernel_size=(1,3), activation='relu')(visible)# -> (4,2,64)
        pool1 = MaxPooling2D(pool_size=(1,2), padding='same')(con1) # 4 - 2 / 1 + 1, 2 - 2 / 
        con2 = Conv2D(128, kernel_size=(1,3), activation='relu')(pool1)
        pool2 = MaxPooling2D(pool_size=(1,1), padding='same')(con2)
        flatten1 = Flatten()(pool2)

        # interpretation layer
        dense1 = Dense(128, activation='relu')(flatten1)
        output = Dense(1)(dense1)
        model = Model(inputs=visible, outputs=output)
        model.compile(loss='mean_squared_error', optimizer='adam')
        monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, mode='min', restore_best_weights=True)
        history = model.fit( x_train, y_train, validation_data=[x_test, y_test], callbacks=[checkpointer, monitor], epochs=500)
        plot_losses(history, iteration_path, i)
if CNN and not INPUT_IS_TWO_DIMENSIONAL:# 1D image of 7 pixels, each pixel with 5 channels
    checkpointer = ModelCheckpoint(filepath=os.path.join(iteration_path, "CNN-best-weights.keras"), save_best_only=True, verbose=0)
    # H_out = floor((H_in + 2*pad_h - kernel_h) / stride_h) + 1
    # W_out = floor((W_in + 2*pad_w - kernel_w) / stride_w) + 1
    # C_out = number of filters

    # H_out = (7 - 4) / 1 + 1 = 4
    # W_out = (5 - 4) / 1 + 1 = 2
    # Channels_out = 64

    for i in range(5):
        visible = Input(shape=(WINDOW_SIZE,5)) 
        con1 = Conv1D(64, kernel_size=1, activation='relu', padding='same')(visible)# -> (4,2,64)
        con2 = Conv1D(64, kernel_size=3, activation='relu', padding='same')(con1)

        pool1 = MaxPooling1D(pool_size=2 )(con2) # 4 - 2 / 1 + 1, 2 - 2 / 
        # con3 = Conv1D(128, kernel_size=1, activation='relu', padding='same')(pool1)
        # con4 = Conv1D(128, kernel_size=3, activation='relu', padding='same')(con3)
        # pool2 = MaxPooling1D(pool_size=2 )(con4) # 4 - 2 / 1 + 1, 2 - 2 / 
        # con5 = Conv1D(128, kernel_size=1, activation='relu', padding='same')(pool2)
        # con6 = Conv1D(128, kernel_size=3, activation='relu', padding='same')(con5)
        flatten1 = Flatten()(pool1)

        # interpretation layer
        dense1 = Dense(32, activation='relu')(flatten1)
        output = Dense(1)(dense1)
        model = Model(inputs=visible, outputs=output)
        model.compile(loss='mean_squared_error', optimizer='adam')
        monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, mode='min', restore_best_weights=True)
        history = model.fit( x_train, y_train, validation_data=[x_test, y_test], callbacks=[checkpointer, monitor], epochs=500)
        plot_losses(history, iteration_path, i)
# Out:
# Epoch 1/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.8452 - val_loss: 3.0522
# Epoch 2/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1225 - val_loss: 2.8874
# Epoch 3/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0247 - val_loss: 3.1190
# Epoch 4/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0030 - val_loss: 3.8360
# Epoch 5/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9562 - val_loss: 2.2816
# Epoch 6/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9913 - val_loss: 6.5113
# Epoch 7/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8370 - val_loss: 2.1505
# Epoch 8/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7820 - val_loss: 5.5796
# Epoch 9/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7484 - val_loss: 3.1475
# Epoch 10/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6898 - val_loss: 2.0673
# Epoch 11/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6836 - val_loss: 2.5174
# Epoch 12/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6873 - val_loss: 1.8478
# Epoch 13/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7679 - val_loss: 1.6428
# Epoch 14/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6311 - val_loss: 2.2236
# Epoch 15/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6130 - val_loss: 3.9659
# Epoch 16/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6038 - val_loss: 2.1339
# Epoch 17/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5671 - val_loss: 2.1200
# Epoch 18/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5903 - val_loss: 2.4848
# Epoch 1/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 16.3856 - val_loss: 3.4999
# Epoch 2/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2160 - val_loss: 4.3561
# Epoch 3/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1751 - val_loss: 6.2800
# Epoch 4/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1363 - val_loss: 4.3506
# Epoch 5/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0608 - val_loss: 2.7113
# Epoch 6/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0189 - val_loss: 3.0724
# Epoch 7/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9499 - val_loss: 5.0844
# Epoch 8/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8763 - val_loss: 2.2968
# Epoch 9/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7943 - val_loss: 2.5457
# Epoch 10/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8565 - val_loss: 1.9258
# Epoch 11/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7925 - val_loss: 1.8871
# Epoch 12/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7515 - val_loss: 5.3318
# Epoch 13/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7463 - val_loss: 2.0054
# Epoch 14/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7301 - val_loss: 2.1934
# Epoch 15/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6256 - val_loss: 1.9041
# Epoch 16/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6643 - val_loss: 2.2855
# Epoch 1/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 25.7524 - val_loss: 3.2856
# Epoch 2/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0675 - val_loss: 3.0274
# Epoch 3/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0637 - val_loss: 3.7140
# Epoch 4/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0008 - val_loss: 4.2283
# Epoch 5/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9792 - val_loss: 3.0701
# Epoch 6/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9330 - val_loss: 3.0152
# Epoch 7/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9353 - val_loss: 3.3748
# Epoch 8/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9016 - val_loss: 2.3250
# Epoch 9/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8538 - val_loss: 2.1102
# Epoch 10/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7782 - val_loss: 1.9947
# Epoch 11/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8528 - val_loss: 1.8695
# Epoch 12/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7674 - val_loss: 4.2765
# Epoch 13/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7131 - val_loss: 3.7811
# Epoch 14/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7113 - val_loss: 2.3262
# Epoch 15/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5756 - val_loss: 1.5520
# Epoch 16/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5616 - val_loss: 3.3811
# Epoch 17/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5439 - val_loss: 2.3593
# Epoch 18/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5462 - val_loss: 2.4732
# Epoch 19/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5636 - val_loss: 1.9717
# Epoch 20/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5879 - val_loss: 1.5951
# Epoch 1/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.0410 - val_loss: 2.7484
# Epoch 2/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9894 - val_loss: 2.7396
# Epoch 3/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9071 - val_loss: 2.7728
# Epoch 4/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9191 - val_loss: 2.4756
# Epoch 5/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8534 - val_loss: 2.3854
# Epoch 6/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8040 - val_loss: 2.3863
# Epoch 7/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7861 - val_loss: 2.2256
# Epoch 8/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7396 - val_loss: 3.0152
# Epoch 9/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7867 - val_loss: 3.5953
# Epoch 10/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6787 - val_loss: 2.0300
# Epoch 11/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6339 - val_loss: 2.4656
# Epoch 12/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6589 - val_loss: 1.8638
# Epoch 13/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6496 - val_loss: 3.0379
# Epoch 14/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6371 - val_loss: 2.1880
# Epoch 15/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6832 - val_loss: 2.4108
# Epoch 16/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6277 - val_loss: 2.6587
# Epoch 17/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6624 - val_loss: 4.7145
# Epoch 1/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 12.7682 - val_loss: 3.8006
# Epoch 2/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1448 - val_loss: 3.0233
# Epoch 3/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0825 - val_loss: 2.7260
# Epoch 4/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0246 - val_loss: 2.7397
# Epoch 5/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9346 - val_loss: 4.0466
# Epoch 6/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9935 - val_loss: 3.7736
# Epoch 7/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9271 - val_loss: 2.9024
# Epoch 8/500
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9167 - val_loss: 2.7364

# %% [markdown]
# ## Evaluate Model

# %%
if CNN:
    metrics_path = "CNN-metrics.txt"
    def redirect(out): # redirect model summary to metrics
        with open(os.path.join(iteration_path, metrics_path), 'a') as file:
            print(out, file=file)
    # make prediction and evaluate
    model.load_weights(os.path.join(iteration_path, "CNN-best-weights.keras"))
    prediction = model.predict(x_test)
    score = np.sqrt(mean_squared_error(y_test, prediction))
    if DEBUG:
        print("Score (RMSE): {}".format(score))
    # Write Metrics to file
    with open(os.path.join(iteration_path, metrics_path), "x") as file:
        file.write(f"Score (RMSE): {score}\nWindow Size: {WINDOW_SIZE}")
    model.summary(print_fn=redirect)
    chart_regression(os.path.join(iteration_path, "CNN-Lift-Chart"), prediction.flatten(), y_test, sort=True)
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Score (RMSE): 1.2457892000217048
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# # Create a RNN

# %% [markdown]
# Read Data In

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf 
from pathlib import Path
import os
import sys
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, Flatten, Conv2D, MaxPooling2D, concatenate, Conv1D, MaxPooling1D
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import roc_curve, auc, mean_squared_error
import matplotlib.pyplot as plt 
from collections.abc import Sequence
from sklearn import preprocessing
# %matplotlib inline
import csv
import glob
from IPython.display import Image
import seaborn as sns

# %%
def plot_losses(history, base_path, iteration:int):
    # Plot training & validation loss over epochs
    plt.plot(history.history["loss"], label="Training Loss")
    plt.plot(history.history["val_loss"], label="Validation Loss")
    plt.ylim(bottom=0.0, top=400.0)
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training vs. Validation Loss")
    plt.legend()
    plt.savefig(
        os.path.join(base_path, f"training-validiation-loss--epoch---Model {iteration}")
    )
    plt.close()


def print_schema(dataframe: pd.DataFrame):
    print('~~~~~~dataframe schema~~~~~~')
    print(f"Dataframe shape: {dataframe.shape} | Dataframe length: {len(dataframe)}")
    print('Column labels: ')
    print(dataframe.columns)
    print('Dataframe head: ')
    print(f"{dataframe.head()}")
def print_column(dataframe: pd.DataFrame, columns: str | list[str]):
    if isinstance(columns, list):
        for i, label in enumerate(columns):
            print(f"column {i}")
            print(dataframe[label])
    else:
        print(dataframe[columns])
# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)


# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_


# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Convert all missing values in the specified column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)


# Convert all missing values in the specified column to the default
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)


# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column. 
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    #if target_type in (np.int64, np.int32):
        ## Classification
        #dummies = pd.get_dummies(df[target])
        #return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    #else#:
        ## Regression
    return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


# Regression chart.
def chart_regression(path, pred,y,sort=True):
    t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
    if sort:
        t.sort_values(by=['y'],inplace=True)
    b = plt.plot(t['pred'].tolist(),label='prediction')
    a = plt.plot(t['y'].tolist(),label='expected')

    plt.ylabel('output')
    plt.legend()
    plt.savefig(path)
    plt.close()

# Remove all rows where the specified column is +/- sd standard deviations
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd * df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)


# Encode a column to a range between normalized_low and normalized_high.
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = min(df[name])
        data_high = max(df[name])

    df[name] = ((df[name] - data_low) / (data_high - data_low)) \
               * (normalized_high - normalized_low) + normalized_low

# %%
DEBUG = True
ITERATION = 58
WINDOW_SIZE = 7
INPUT_IS_TWO_DIMENSIONAL = False
EXPLORE = False
FCN = False
CNN = True
RNN = False

# %%
base_path = os.path.join(os.getcwd(), "output")
iteration_path = os.path.join(base_path, f"iteration-{ITERATION}")
try:
    os.mkdir(base_path)
except FileExistsError as e:
    print(f"{base_path} already exists")
except OSError as e:
    print(f"Error creating directory: {base_path}")
try:
    os.mkdir(iteration_path)
except FileExistsError as e:
    print(f"{iteration_path} already exists. Exiting to preserve previous work.")
    sys.exit(0)
except OSError:
    print("An error occurred while creating the folder. ")
# Out:
# c:\Users\timef\Documents\Workspaces\Python\csc180\stock-price-predictor\output already exists

# %%
df = pd.read_csv("./data/JPM.csv", dtype={'Volume':np.float32})
print(df.shape)
# Out:
# (9556, 7)

# %% [markdown]
# ### Clean Dataset

# %%
df.drop(['Date', 'Adj Close'], axis=1, inplace=True)

# %%
print(df.shape)
# Out:
# (9556, 5)

# %%
df_copy = df.copy(deep=True)
missing_median(df_copy, 'Close')
for column in df.columns:
    missing_median(df, column)
    encode_numeric_zscore(df, column)

# %%
split_at_index = int(len(df) * 0.7)
df_train = df[:split_at_index]
df_test = df[split_at_index:]

df_copy_train = df_copy[:split_at_index]
df_copy_test = df_copy[split_at_index:]
close_train = df_copy_train['Close']
close_test = df_copy_test['Close']

# %%
print(df_train.shape)
print(df_test.shape)
print(close_test.shape)
# Out:
# (6689, 5)
# (2867, 5)
# (2867,)

# %%
def window_it(window_size, dataframe_train, dataframe_test):
    x= []
    y = []
    for i in range(len(dataframe_train) - window_size):
        window = dataframe_train.iloc[i:i+window_size][['Open', 'High', 'Low', 'Volume', 'Close']].values
        x.append(window)
        y.append(dataframe_test.iloc[i+window_size])
        if DEBUG and i == 1:
            print(f"window shape:  {window.shape}\n {window}\nx shape:\n {x[:1]}\ny: \n{y[:1]}")
    return np.array(x), np.array(y)

# %%
x_train, y_train = window_it(WINDOW_SIZE, df_train, close_train)
x_test, y_test = window_it(WINDOW_SIZE, df_test, close_test)
# Out:
# window shape:  (7, 5)
#  [[-0.54816568 -0.5489015  -0.54722446 -0.50387412 -0.54809776]
#  [-0.54894298 -0.54967237 -0.5480084  -0.7057299  -0.54887493]
#  [-0.54874865 -0.54943146 -0.54776341 -0.76122087 -0.54863205]
#  [-0.54845718 -0.54914238 -0.54746945 -0.79860157 -0.54834063]
#  [-0.54782561 -0.54851607 -0.54683249 -0.87001157 -0.54770917]
#  [-0.54729121 -0.54798609 -0.54629351 -0.9024297  -0.54717486]
#  [-0.5468054  -0.5475043  -0.54580355 -0.87484533 -0.54668913]]
# x shape:
#  [array([[-0.54763128, -0.54832334, -0.54663649,  0.33957607, -0.54751487],
#        [-0.54816568, -0.5489015 , -0.54722446, -0.50387412, -0.54809776],
#        [-0.54894298, -0.54967237, -0.5480084 , -0.7057299 , -0.54887493],
#        [-0.54874865, -0.54943146, -0.54776341, -0.76122087, -0.54863205],
#        [-0.54845718, -0.54914238, -0.54746945, -0.79860157, -0.54834063],
#        [-0.54782561, -0.54851607, -0.54683249, -0.87001157, -0.54770917],
#        [-0.54729121, -0.54798609, -0.54629351, -0.9024297 , -0.54717486]])]
# y:
# [np.float64(0.551339)]
# window shape:  (7, 5)
#  [[-0.17111633 -0.17398699 -0.17248353  1.7033509  -0.17426456]
#  [-0.17366588 -0.17506623 -0.17690501  1.57239771 -0.18082391]
#  [-0.18041291 -0.17620711 -0.17935095  1.48473835 -0.17351844]
#  [-0.17372806 -0.17571374 -0.17414551  0.8081075  -0.17631631]
#  [-0.17267095 -0.1737403  -0.17828479  1.76773584 -0.17836806]
#  [-0.17332389 -0.17710133 -0.18562259  2.85992908 -0.18673045]
#  [-0.18380195 -0.18314493 -0.1839292   1.79447472 -0.17976696]]
# x shape:
#  [array([[-0.17550032, -0.17346283, -0.17364378,  1.61006856, -0.16981908],
#        [-0.17111633, -0.17398699, -0.17248353,  1.7033509 , -0.17426456],
#        [-0.17366588, -0.17506623, -0.17690501,  1.57239771, -0.18082391],
#        [-0.18041291, -0.17620711, -0.17935095,  1.48473835, -0.17351844],
#        [-0.17372806, -0.17571374, -0.17414551,  0.8081075 , -0.17631631],
#        [-0.17267095, -0.1737403 , -0.17828479,  1.76773584, -0.17836806],
#        [-0.17332389, -0.17710133, -0.18562259,  2.85992908, -0.18673045]])]
# y:
# [np.float64(17.412857)]

# %%
if DEBUG:
    print(x_train.shape)
    print(x_test.shape)
    print(y_train.shape)
    print(y_test.shape)
# Out:
# (6682, 7, 5)
# (2860, 7, 5)
# (6682,)
# (2860,)

# %% [markdown]
# ### Create the Model

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import Adam
checkpointer = ModelCheckpoint(filepath=os.path.join(iteration_path, "RNN-best-weights.keras"), save_best_only=True)

for i in range(3):
    print(f"training model {i}")
    optimizer = Adam(learning_rate=0.005)
    visible = Input(shape=(WINDOW_SIZE,  5))
    lstm1 = LSTM(70, dropout=0.1, recurrent_dropout=0.1, activation='tanh')(visible)


    #lstm5 = LSTM(32, dropout=0.1)(lstm1)
    dense1= Dense(16, activation='relu')(lstm1)
    #dense2 = Dense(8, activation='relu')(lstm1)
    output = Dense(1)(dense1)
    model = Model(inputs=visible, outputs=output)
    model.compile(loss="mean_squared_error", optimizer = 'adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
    history = model.fit(x_train, y_train, validation_data = [x_test, y_test], callbacks=[checkpointer, monitor], epochs=200, verbose=2)
    plot_losses(history, iteration_path, i)
# Out:
# training model 0
# Epoch 1/200
# 209/209 - 3s - 13ms/step - loss: 4.2340 - val_loss: 9232.6084
# Epoch 2/200
# 209/209 - 1s - 3ms/step - loss: 2.0540 - val_loss: 9174.3809
# Epoch 3/200
# 209/209 - 1s - 3ms/step - loss: 1.4191 - val_loss: 9276.0127
# Epoch 4/200
# 209/209 - 1s - 3ms/step - loss: 1.1299 - val_loss: 9318.5459
# Epoch 5/200
# 209/209 - 1s - 3ms/step - loss: 1.0362 - val_loss: 9298.4648
# Epoch 6/200
# 209/209 - 1s - 3ms/step - loss: 0.9282 - val_loss: 9284.9209
# Epoch 7/200
# 209/209 - 1s - 3ms/step - loss: 0.9473 - val_loss: 9260.4688
# Epoch 7: early stopping
# training model 1
# Epoch 1/200
# 209/209 - 3s - 14ms/step - loss: 4.6963 - val_loss: 9192.0449
# Epoch 2/200
# 209/209 - 1s - 4ms/step - loss: 2.1506 - val_loss: 9114.3877
# Epoch 3/200
# 209/209 - 1s - 4ms/step - loss: 1.5129 - val_loss: 9229.0156
# Epoch 4/200
# 209/209 - 1s - 4ms/step - loss: 1.1771 - val_loss: 9212.8828
# Epoch 5/200
# 209/209 - 1s - 4ms/step - loss: 1.0794 - val_loss: 9193.8857
# Epoch 6/200
# 209/209 - 1s - 4ms/step - loss: 1.0277 - val_loss: 9228.7754
# Epoch 7/200
# 209/209 - 1s - 4ms/step - loss: 0.9465 - val_loss: 9246.3076
# Epoch 7: early stopping
# training model 2
# Epoch 1/200
# 209/209 - 3s - 14ms/step - loss: 4.4594 - val_loss: 9117.6475
# Epoch 2/200
# 209/209 - 1s - 3ms/step - loss: 2.1157 - val_loss: 9033.9834
# Epoch 3/200
# 209/209 - 1s - 3ms/step - loss: 1.3517 - val_loss: 9116.1416
# Epoch 4/200
# 209/209 - 1s - 3ms/step - loss: 1.1235 - val_loss: 9115.0938
# Epoch 5/200
# 209/209 - 1s - 3ms/step - loss: 0.9951 - val_loss: 9088.8604
# Epoch 6/200
# 209/209 - 1s - 3ms/step - loss: 1.0239 - val_loss: 9076.5537
# Epoch 7/200
# 209/209 - 1s - 3ms/step - loss: 0.9730 - val_loss: 9094.0850
# Epoch 7: early stopping

# %% [markdown]
# ### Evaluate and Write Results

# %%
metrics_path = "RNN-metrics.txt"
def redirect(out): # redirect model summary to metrics
    with open(os.path.join(iteration_path, metrics_path), 'a') as file:
        print(out, file=file)
# make prediction and evaluate
model.load_weights(os.path.join(iteration_path, "RNN-best-weights.keras"))
prediction = model.predict(x_test)
score = np.sqrt(mean_squared_error(y_test, prediction))
if DEBUG:
    print("Score (RMSE): {}".format(score))
# Write Metrics to file
with open(os.path.join(iteration_path, metrics_path), "x") as file:
    file.write(f"Score (RMSE): {score}\nWindow Size: {WINDOW_SIZE}")
model.summary(print_fn=redirect)
chart_regression(os.path.join(iteration_path, "RNN-Lift-Chart"), prediction.flatten(), y_test, sort=True)
# Out:
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Score (RMSE): 95.04725966643242
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
